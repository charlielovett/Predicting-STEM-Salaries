# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import statsmodels.formula.api as sm
data = pd.read_csv('./Data/salary_data_cleaned.csv')
import warnings
warnings.filterwarnings("ignore")

# %%
data.head()
# Out:
#    Unnamed: 0    company level              title  totalyearlycompensation  \
# 0       15710     google    L6  Software Engineer                   400000
# 1       23532  microsoft    61  Software Engineer                   136000
# 2       23533     google    L5  Software Engineer                   337000
# 3       23534  microsoft    62  Software Engineer                   222000
# 4       23535      blend   IC3  Software Engineer                   187000
#
#             location  yearsofexperience  yearsatcompany  \
# 0      Sunnyvale, CA                5.0             5.0
# 1        Redmond, WA                3.0             2.0
# 2      San Bruno, CA                6.0             6.0
# 3        Seattle, WA                4.0             4.0
# 4  San Francisco, CA                5.0             0.0
#
#                               tag gender  ...  Masters_Degree  \
# 0  Distributed Systems (Back-End)   Male  ...               0
# ...

# %%
data.totalyearlycompensation.describe()
# Out:
# count    2.159100e+04
# mean     1.978458e+05
# std      1.330927e+05
# min      1.000000e+04
# 25%      1.190000e+05
# 50%      1.730000e+05
# 75%      2.450000e+05
# max      4.980000e+06
# Name: totalyearlycompensation, dtype: float64

# %%
model = sm.ols(formula = 'totalyearlycompensation~company+title+location+yearsofexperience+yearsatcompany+gender+cityid+dmaid+Masters_Degree+Bachelors_Degree+Doctorate_Degree+Highschool+Some_College+Race_Asian+Race_White+Race_Two_Or_More+Race_Black+Race_Hispanic', data = data).fit()
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                OLS Regression Results
# ...
# Dep. Variable:     totalyearlycompensation   R-squared:                       0.597
# Model:                                 OLS   Adj. R-squared:                  0.560
# Method:                      Least Squares   F-statistic:                     15.93
# Date:                     Tue, 16 May 2023   Prob (F-statistic):               0.00
# Time:                             15:44:31   Log-Likelihood:            -2.7554e+05
# No. Observations:                    21589   AIC:                         5.548e+05
# Df Residuals:                        19748   BIC:                         5.694e+05
# Df Model:                             1840
# Covariance Type:                 nonrobust
# ...
#                                                           coef    std err          t      P>|t|      [0.025      0.975]
# ...

# %%
pred = model.predict(data)

# %%
(np.abs(data.totalyearlycompensation - pred)).mean()
# Out:
# 45413.34597067733
